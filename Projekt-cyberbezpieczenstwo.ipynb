# %%
import pandas as pd

# %%
df = pd.read_csv('eksport_danych.csv')

# %%
df.head()
# Out:
#    ID                                    Title                  Category  \
# 0   1  Authentication Bypass via SQL Injection           Mobile Security
# 1   2                Union-Based SQL Injection  AI Agents & LLM Exploits
# 2   3                Error-Based SQL Injection  AI Agents & LLM Exploits
# 3   4                      Blind SQL Injection  AI Agents & LLM Exploits
# 4   5               Second-Order SQL Injection  AI Agents & LLM Exploits
#
#             Attack Type                               Scenario Description  \
# 0  SQL Injection (SQLi)  A login form fails to validate or sanitize inp...
# 1         SQL Injection  This attack occurs when a hacker uses the SQL ...
# 2         SQL Injection  This attack occurs when an attacker intentiona...
# 3         SQL Injection  In Blind SQL Injection, the attacker doesn’t s...
# 4         SQL Injection  In a Second-Order SQL Injection, the attacker ...
#
#                                           Tools Used  \
# ...

# %%
df.describe(include='all')
# Out:
#                   ID                                Title        Category  \
# count   14133.000000                                14133           14133
# unique           NaN                                13793              64
# top              NaN  Beacon Over HTTPS via Cobalt Strike  Insider Threat
# freq             NaN                                    3             569
# mean     7067.000000                                  NaN             NaN
# std      4079.990012                                  NaN             NaN
# min         1.000000                                  NaN             NaN
# 25%      3534.000000                                  NaN             NaN
# 50%      7067.000000                                  NaN             NaN
# 75%     10600.000000                                  NaN             NaN
# max     14133.000000                                  NaN             NaN
#
#                             Attack Type  \
# ...

# %%
df.describe()
# Out:
#                  ID
# count  14133.000000
# mean    7067.000000
# std     4079.990012
# min        1.000000
# 25%     3534.000000
# 50%     7067.000000
# 75%    10600.000000
# max    14133.000000

# %%
df.dtypes
# Out:
# ID                       int64
# Title                   object
# Category                object
# Attack Type             object
# Scenario Description    object
# Tools Used              object
# Attack Steps            object
# Target Type             object
# Vulnerability           object
# MITRE Technique         object
# Impact                  object
# Detection Method        object
# Solution                object
# Tags                    object
# Source                  object
# Unnamed: 15             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14133 entries, 0 to 14132
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    14133 non-null  int64
#  1   Title                 14133 non-null  object
#  2   Category              14133 non-null  object
#  3   Attack Type           14133 non-null  object
#  4   Scenario Description  14133 non-null  object
#  5   Tools Used            14119 non-null  object
#  6   Attack Steps          14133 non-null  object
#  7   Target Type           14129 non-null  object
#  8   Vulnerability         14115 non-null  object
#  9   MITRE Technique       14109 non-null  object
#  10  Impact                14130 non-null  object
#  11  Detection Method      14129 non-null  object
#  12  Solution              14130 non-null  object
#  13  Tags                  14130 non-null  object
#  14  Source                13973 non-null  object
# ...

# %%
df.nunique()
# Out:
# ID                      14133
# Title                   13793
# Category                   64
# Attack Type              8834
# Scenario Description    13866
# Tools Used              12935
# Attack Steps            13895
# Target Type              9885
# Vulnerability           13424
# MITRE Technique          5770
# Impact                  13187
# Detection Method        13813
# Solution                13852
# Tags                    13817
# Source                   7051
# Unnamed: 15                 2
# dtype: int64

# %%
df['Category'].unique()
# Out:
# array([' Mobile Security', 'AI Agents & LLM Exploits', 'AI/ML Security',
#        'Cloud Security', 'Mobile Security', 'Network Security',
#        'Operating System Exploits', 'Network security',
#        'Web Application Security', 'AI Data Leakage & Privacy Risks',
#        'Blockchain / Web3', 'Cryptography Attacks', 'SCADA/ICS',
#        'IoT / Embedded Devices', 'Insider Threat',
#        'Physical / Hardware Attacks', 'Malware & Threat',
#        'Email & Messaging Protocol Exploits',
#        'Wireless Attacks (Advanced)',
#        'Quantum Cryptography & Post-Quantum Threats', 'Red Team',
#        'Blue Team', 'DevSecOps & CI/CD Security',
#        'Virtualization & Container Security → Defensive Evasion & Persistence → 🛡️ Evading Container Security Tools',
#        'Browser Security → Cross-Site Scripting (XSS)',
#        'Browser Security → Clickjacking / UI Redressing',
#        'Browser Security → Tabnabbing / Tab Hijacking',
# ...

# %%
df['Category'].value_counts()
# Out:
# Category
# Insider Threat                                                   569
# Physical / Hardware Attacks                                      548
# Quantum Cryptography & Post-Quantum Threats                      542
# Wireless Attacks (Advanced)                                      535
# Malware & Threat                                                 528
#                                                                 ...
# Automotive / Cyber-Physical Systems → ECU Reverse Engineering      7
# Automotive / CPS → Firmware Over-The-Air (FOTA) Abuse              5
# Automotive / CPS → Physical Layer Attack                           3
# Network security                                                   2
#  Mobile Security                                                   1
# Name: count, Length: 64, dtype: int64

# %%
df.isnull().sum()
# Out:
# ID                          0
# Title                       0
# Category                    0
# Attack Type                 0
# Scenario Description        0
# Tools Used                 14
# Attack Steps                0
# Target Type                 4
# Vulnerability              18
# MITRE Technique            24
# Impact                      3
# Detection Method            4
# Solution                    3
# Tags                        3
# Source                    160
# Unnamed: 15             14087
# dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'Title', 'Category', 'Attack Type', 'Scenario Description',
#        'Tools Used', 'Attack Steps ', 'Target Type', 'Vulnerability',
#        'MITRE Technique', 'Impact', 'Detection Method', 'Solution', 'Tags',
#        'Source', 'Unnamed: 15'],
#       dtype='object')

# %%
df['Attack Steps '].str.rstrip()
# Out:
# 0        1. Reconnaissance: Find a login form on the we...
# 1        1. Identify User Input Points: Attacker finds ...
# 2        1. Identify Input Points:Attacker finds a fiel...
# 3        1. Find a User Input Point:Attacker finds a pl...
# 4        1. Identify Stored Input Fields:The attacker l...
#                                ...
# 14128    1. Simulate spoofed and legitimate satellite t...
# 14129    1. Host a multi-agency workshop including mili...
# 14130    1. Design a containerized satellite simulation...
# 14131    1. Create a firmware scanning tool targeting s...
# 14132    1. Identify cyber standards applicable to sate...
# Name: Attack Steps , Length: 14133, dtype: object

# %%
df.columns = df.columns.str.strip()

# %%
print(df.columns.tolist())
# Out:
# ['ID', 'Title', 'Category', 'Attack Type', 'Scenario Description', 'Tools Used', 'Attack Steps', 'Target Type', 'Vulnerability', 'MITRE Technique', 'Impact', 'Detection Method', 'Solution', 'Tags', 'Source', 'Unnamed: 15']

# %%
df = df.drop('Unnamed: 15', axis = 1)

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [ID, Title, Category, Attack Type, Scenario Description, Tools Used, Attack Steps, Target Type, Vulnerability, MITRE Technique, Impact, Detection Method, Solution, Tags, Source]
# Index: []
